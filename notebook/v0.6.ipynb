# %% [markdown]
# Version 0.6
# ====
#
# 추가한 내용
# ----
# * gazetteer one hot 벡터 자질의 오류를 수정한 것

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# CNN7
# ----
#
# ### 음절, 임베딩 200

# %%
cnn7 = pd.DataFrame.from_csv('v0.6/cnn7.200.tsv', sep='\t')
cnn7[:10]
# Out:
#           loss  accuracy   f-score
# iter
# 1     0.175420  0.903525  0.355537
# 2     0.478444  0.916664  0.474632
# 3     0.015106  0.922482  0.516077
# 4     0.243786  0.890499  0.362482
# 5     0.114719  0.935133  0.612338
# 6     0.025928  0.937836  0.641524
# 7     0.011559  0.933931  0.625776
# 8     0.743105  0.934945  0.621273
# 9     0.002185  0.938511  0.651126
# 10    0.002627  0.934945  0.624951

# %%
cnn7.loss.plot(figsize=(15, 10))

# %%
print(max(cnn7['f-score']))
cnn7.plot(y=['accuracy', 'f-score'], figsize=(15, 10))
# Out:
# 0.710072769054
