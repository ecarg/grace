# %% [markdown]
# Version 0.2
# ====
#
# 추가된 내용
# ----
# * vocabulary 생성 시 최소 빈도로 컷오프 적용
# * 자소 => 음절 convolution을 적용

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# FNN
# ----
#
# ### 음절(chr), 자소(pho)

# %%
fnn_chr = pd.DataFrame.from_csv('v0.2/fnn.chr.tsv', sep='\t')
fnn_chr.columns = ['loss.chr', 'accuracy.chr', 'f-score.chr']
print(fnn_chr[:5])
print()
fnn_pho = pd.DataFrame.from_csv('v0.2/fnn.pho.tsv', sep='\t')
fnn_pho.columns = ['loss.pho', 'accuracy.pho', 'f-score.pho']
print(fnn_pho[:5])
fnn = pd.concat([fnn_chr, fnn_pho])
fnn[:10]
# Out:
#       loss.chr  accuracy.chr  f-score.chr
# iter
# 1     1.242144      0.832013     0.146037
# 2     0.193126      0.870115     0.190669
# 3     0.219931      0.882466     0.256692
# 4     0.289376      0.882053     0.249511
# 5     0.139867      0.887683     0.288056
#
#       loss.pho  accuracy.pho  f-score.pho
# iter
# 1     0.772515      0.847554     0.141616
# 2     0.269248      0.846240     0.090540
# 3     0.205784      0.860130     0.201220
# 4     0.629438      0.860731     0.187358
# 5     0.438783      0.860393     0.189441
#       accuracy.chr  accuracy.pho  f-score.chr  f-score.pho  loss.chr  loss.pho
# iter
# 1         0.832013           NaN     0.146037          NaN  1.242144       NaN
# 2         0.870115           NaN     0.190669          NaN  0.193126       NaN
# 3         0.882466           NaN     0.256692          NaN  0.219931       NaN
# 4         0.882053           NaN     0.249511          NaN  0.289376       NaN
# 5         0.887683           NaN     0.288056          NaN  0.139867       NaN
# 6         0.893877           NaN     0.322924          NaN  0.151293       NaN
# 7         0.896693           NaN     0.336857          NaN  0.466734       NaN
# 8         0.901047           NaN     0.345126          NaN  0.190622       NaN
# 9         0.899621           NaN     0.355185          NaN  0.128941       NaN
# 10        0.904801           NaN     0.377032          NaN  0.466195       NaN

# %%
fnn.plot(y=['loss.chr', 'loss.pho'], figsize=(15, 10))

# %%
print(max(fnn['f-score.chr']), max(fnn['f-score.pho']))
fnn.plot(y=['accuracy.chr', 'accuracy.pho', 'f-score.chr', 'f-score.pho'], figsize=(15, 10))
# Out:
# 0.55650979045 nan

# %% [markdown]
# CNN
# ----
#
# ### 음절(chr), 자소(pho)

# %%
cnn_chr = pd.DataFrame.from_csv('v0.2/cnn.chr.tsv', sep='\t')
cnn_chr.columns = ['loss.chr', 'accuracy.chr', 'f-score.chr']
print(cnn_chr[:5])
print()
cnn_pho = pd.DataFrame.from_csv('v0.2/cnn.pho.tsv', sep='\t')
cnn_pho.columns = ['loss.pho', 'accuracy.pho', 'f-score.pho']
print(cnn_pho[:5])
cnn = pd.concat([cnn_chr, cnn_pho])
cnn[:10]
# Out:
#       loss.chr  accuracy.chr  f-score.chr
# iter
# 1     0.433052      0.864635     0.201696
# 2     0.158390      0.877435     0.241700
# 3     0.681327      0.880814     0.296534
# 4     0.275291      0.896768     0.350374
# 5     0.327422      0.901423     0.367948
#
#       loss.pho  accuracy.pho  f-score.pho
# iter
# 1     1.508569      0.851458     0.135453
# 2     0.688026      0.862908     0.249636
# 3     0.614169      0.847479     0.262053
# 4     0.415677      0.876009     0.272406
# 5     0.422470      0.889223     0.362583
#       accuracy.chr  accuracy.pho  f-score.chr  f-score.pho  loss.chr  loss.pho
# iter
# 1         0.864635           NaN     0.201696          NaN  0.433052       NaN
# 2         0.877435           NaN     0.241700          NaN  0.158390       NaN
# 3         0.880814           NaN     0.296534          NaN  0.681327       NaN
# 4         0.896768           NaN     0.350374          NaN  0.275291       NaN
# 5         0.901423           NaN     0.367948          NaN  0.327422       NaN
# 6         0.907729           NaN     0.380850          NaN  0.431946       NaN
# 7         0.903450           NaN     0.385154          NaN  0.938435       NaN
# 8         0.909193           NaN     0.404723          NaN  0.330940       NaN
# 9         0.915312           NaN     0.438336          NaN  0.526204       NaN
# 10        0.914636           NaN     0.424242          NaN  0.131355       NaN

# %%
cnn.plot(y=['loss.chr', 'loss.pho'], figsize=(15, 10))

# %%
print(max(cnn['f-score.chr']), max(cnn['f-score.pho']))
cnn.plot(y=['accuracy.chr', 'accuracy.pho', 'f-score.chr', 'f-score.pho'], figsize=(15, 10))
# Out:
# 0.667379679144 nan
