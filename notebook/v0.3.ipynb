# %% [markdown]
# Version 0.3
# ====
#
# 수정된 내용
# ----
# * 3-gram convolution만 이용하여 CNN 모델 변경

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# FNN
# ----
#
# ### 음절(chr), 자소(pho)

# %%
fnn_chr = pd.DataFrame.from_csv('v0.3/fnn3.chr.tsv', sep='\t')
fnn_chr.columns = ['loss.chr', 'accuracy.chr', 'f-score.chr']
print(fnn_chr[:5])
print()
fnn_pho = pd.DataFrame.from_csv('v0.3/fnn3.pho.tsv', sep='\t')
fnn_pho.columns = ['loss.pho', 'accuracy.pho', 'f-score.pho']
print(fnn_pho[:5])
fnn = pd.concat([fnn_chr, fnn_pho])
fnn[:10]
# Out:
#       loss.chr  accuracy.chr  f-score.chr
# iter
# 1     0.500607      0.842599     0.064997
# 2     0.475759      0.846616     0.097229
# 3     0.217208      0.856864     0.112676
# 4     1.107416      0.843913     0.182256
# 5     0.261333      0.865235     0.226967
#
#       loss.pho  accuracy.pho  f-score.pho
# iter
# 1     0.982514      0.835880     0.049909
# 2     0.243989      0.847479     0.104895
# 3     0.767011      0.856564     0.172091
# 4     0.242277      0.855850     0.112206
# 5     0.409951      0.855963     0.165114
#       accuracy.chr  accuracy.pho  f-score.chr  f-score.pho  loss.chr  loss.pho
# iter
# 1         0.842599           NaN     0.064997          NaN  0.500607       NaN
# 2         0.846616           NaN     0.097229          NaN  0.475759       NaN
# 3         0.856864           NaN     0.112676          NaN  0.217208       NaN
# 4         0.843913           NaN     0.182256          NaN  1.107416       NaN
# 5         0.865235           NaN     0.226967          NaN  0.261333       NaN
# 6         0.866587           NaN     0.200387          NaN  0.508373       NaN
# 7         0.867112           NaN     0.146628          NaN  0.329869       NaN
# 8         0.876609           NaN     0.199237          NaN  0.118181       NaN
# 9         0.880063           NaN     0.204593          NaN  0.305770       NaN
# 10        0.871692           NaN     0.137151          NaN  0.978626       NaN

# %%
fnn.plot(y=['loss.chr', 'loss.pho'], figsize=(15, 10))

# %%
print(max(fnn['f-score.chr']), max(fnn['f-score.pho']))
fnn.plot(y=['accuracy.chr', 'accuracy.pho', 'f-score.chr', 'f-score.pho'], figsize=(15, 10))
# Out:
# 0.600143575018 nan

# %% [markdown]
# CNN
# ----
#
# ### 음절(chr), 자소(pho)

# %%
cnn_chr = pd.DataFrame.from_csv('v0.3/cnn3.chr.tsv', sep='\t')
cnn_chr.columns = ['loss.chr', 'accuracy.chr', 'f-score.chr']
print(cnn_chr[:5])
print()
cnn_pho = pd.DataFrame.from_csv('v0.3/cnn3.pho.tsv', sep='\t')
cnn_pho.columns = ['loss.pho', 'accuracy.pho', 'f-score.pho']
print(cnn_pho[:5])
cnn = pd.concat([cnn_chr, cnn_pho])
cnn[:10]
# Out:
#       loss.chr  accuracy.chr  f-score.chr
# iter
# 1     2.865411      0.838057     0.022911
# 2     0.258386      0.844401     0.080931
# 3     0.356882      0.853298     0.114727
# 4     0.316117      0.867750     0.192881
# 5     0.355345      0.869928     0.258887
#
#       loss.pho  accuracy.pho  f-score.pho
# iter
# 1     0.209213      0.827921     0.000000
# 2     0.255662      0.835016     0.098167
# 3     0.788796      0.851721     0.128385
# 4     0.600064      0.856226     0.134409
# 5     0.621434      0.850107     0.153576
#       accuracy.chr  accuracy.pho  f-score.chr  f-score.pho  loss.chr  loss.pho
# iter
# 1         0.838057           NaN     0.022911          NaN  2.865411       NaN
# 2         0.844401           NaN     0.080931          NaN  0.258386       NaN
# 3         0.853298           NaN     0.114727          NaN  0.356882       NaN
# 4         0.867750           NaN     0.192881          NaN  0.316117       NaN
# 5         0.869928           NaN     0.258887          NaN  0.355345       NaN
# 6         0.877210           NaN     0.273647          NaN  0.798876       NaN
# 7         0.880664           NaN     0.263815          NaN  0.143183       NaN
# 8         0.887796           NaN     0.303723          NaN  0.512969       NaN
# 9         0.878299           NaN     0.270006          NaN  0.588048       NaN
# 10        0.887571           NaN     0.307885          NaN  0.937966       NaN

# %%
cnn.plot(y=['loss.chr', 'loss.pho'], figsize=(15, 10))

# %%
print(max(cnn['f-score.chr']), max(cnn['f-score.pho']))
cnn.plot(y=['accuracy.chr', 'accuracy.pho', 'f-score.chr', 'f-score.pho'], figsize=(15, 10))
# Out:
# 0.584190003545 nan
