# %% [markdown]
# Version 0.1
# ====
#
# 오류가 있던 것을 모두 수정하고 최초로 제대로된 F-Score를 측정한 버전

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# FNN
# ----

# %%
fnn = pd.DataFrame.from_csv('v0.1/fnn.tsv', sep='\t')
fnn[:10]
# Out:
#           loss  accuracy   f-score
# iter
# 1     0.716045  0.850332  0.122409
# 2     0.134250  0.863959  0.165680
# 3     0.173439  0.870491  0.176471
# 4     0.772527  0.881227  0.238575
# 5     0.636156  0.884042  0.311671
# 6     0.620243  0.893277  0.320997
# 7     0.484706  0.895754  0.322134
# 8     0.233704  0.894928  0.326957
# 9     0.428996  0.900785  0.364251
# 10    0.802590  0.902136  0.357143

# %%
fnn['loss'].plot(figsize=(15, 10))

# %%
print(max(fnn['f-score']))
fnn.plot(y=['accuracy', 'f-score'], figsize=(15, 10))
# Out:
# 0.548076923077

# %% [markdown]
# CNN
# ----

# %%
cnn = pd.DataFrame.from_csv('v0.1/cnn.tsv', sep='\t')
cnn[:10]
# Out:
#           loss   accuracy   f-score
# iter
# 1     0.368323  86.211945  0.189795
# 2     0.602444  87.811104  0.234053
# 3     0.637702  89.072413  0.275543
# 4     0.260565  89.297646  0.337820
# 5     0.582339  89.586696  0.318865
# 6     0.207737  90.998161  0.381927
# 7     0.390565  90.941852  0.373561
# 8     0.755262  91.437366  0.381653
# 9     0.290107  91.001914  0.375686
# 10    0.149385  91.471151  0.423193

# %%
fnn['loss'].plot(figsize=(15, 10))

# %%
print(max(fnn['f-score']))
fnn.plot(y=['accuracy', 'f-score'], figsize=(15, 10))
# Out:
# 0.548076923077
