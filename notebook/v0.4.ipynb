# %% [markdown]
# Version 0.4
# ====
#
# 추가한 내용
# ----
# * gazetteer 매핑 여부를 one hot 벡터로 만들어 각 음절 뒤에 추가
# * 50 임베딩 차원 => 50 임베딩 차원 + 15 one hot 차원

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# FNN
# ----
#
# ### 음절(chr), 자소(pho)

# %%
fnn_chr = pd.DataFrame.from_csv('v0.4/fnn4.chr.tsv', sep='\t')
fnn_chr.columns = ['loss.chr', 'accuracy.chr', 'f-score.chr']
print(fnn_chr[:5])
print()
fnn_pho = pd.DataFrame.from_csv('v0.4/fnn4.pho.tsv', sep='\t')
fnn_pho.columns = ['loss.pho', 'accuracy.pho', 'f-score.pho']
print(fnn_pho[:5])
fnn = pd.concat([fnn_chr, fnn_pho])
fnn[:10]
# Out:
#       loss.chr  accuracy.chr  f-score.chr
# iter
# 1     0.602565      0.830211     0.124625
# 2     0.812702      0.859529     0.152305
# 3     0.370796      0.864071     0.186282
# 4     0.600351      0.882203     0.260769
# 5     0.671274      0.878374     0.224115
#
#       loss.pho  accuracy.pho  f-score.pho
# iter
# 1     1.242290      0.831338     0.103435
# 2     1.090699      0.845903     0.103093
# 3     0.605804      0.843725     0.150475
# 4     0.320007      0.849281     0.158043
# 5     0.513005      0.854649     0.169218
#       accuracy.chr  accuracy.pho  f-score.chr  f-score.pho  loss.chr  loss.pho
# iter
# 1         0.830211           NaN     0.124625          NaN  0.602565       NaN
# 2         0.859529           NaN     0.152305          NaN  0.812702       NaN
# 3         0.864071           NaN     0.186282          NaN  0.370796       NaN
# 4         0.882203           NaN     0.260769          NaN  0.600351       NaN
# 5         0.878374           NaN     0.224115          NaN  0.671274       NaN
# 6         0.889072           NaN     0.295672          NaN  1.823508       NaN
# 7         0.889711           NaN     0.283789          NaN  0.036783       NaN
# 8         0.888209           NaN     0.330172          NaN  0.184840       NaN
# 9         0.894028           NaN     0.340768          NaN  0.015675       NaN
# 10        0.895567           NaN     0.361546          NaN  0.056711       NaN

# %%
fnn.plot(y=['loss.chr', 'loss.pho'], figsize=(15, 10))

# %%
print(max(fnn['f-score.chr']), max(fnn['f-score.pho']))
fnn.plot(y=['accuracy.chr', 'accuracy.pho', 'f-score.chr', 'f-score.pho'], figsize=(15, 10))
# Out:
# 0.541851725316 nan

# %% [markdown]
# CNN
# ----
#
# ### 음절(chr), 자소(pho)

# %%
cnn_chr = pd.DataFrame.from_csv('v0.4/cnn4.chr.tsv', sep='\t')
cnn_chr.columns = ['loss.chr', 'accuracy.chr', 'f-score.chr']
print(cnn_chr[:5])
print()
cnn_pho = pd.DataFrame.from_csv('v0.4/cnn4.pho.tsv', sep='\t')
cnn_pho.columns = ['loss.pho', 'accuracy.pho', 'f-score.pho']
print(cnn_pho[:5])
cnn = pd.concat([cnn_chr, cnn_pho])
cnn[:10]
# Out:
#       loss.chr  accuracy.chr  f-score.chr
# iter
# 1     1.035565      0.843388     0.104987
# 2     0.391899      0.855362     0.142483
# 3     0.883990      0.857953     0.221810
# 4     0.218116      0.869702     0.257790
# 5     0.055433      0.880589     0.268968
#
#       loss.pho  accuracy.pho  f-score.pho
# iter
# 1     0.544456      0.827884     0.000000
# 2     0.243722      0.841473     0.076517
# 3     0.683435      0.857727     0.175814
# 4     0.220479      0.862945     0.213256
# 5     0.552149      0.867938     0.186327
#       accuracy.chr  accuracy.pho  f-score.chr  f-score.pho  loss.chr  loss.pho
# iter
# 1         0.843388           NaN     0.104987          NaN  1.035565       NaN
# 2         0.855362           NaN     0.142483          NaN  0.391899       NaN
# 3         0.857953           NaN     0.221810          NaN  0.883990       NaN
# 4         0.869702           NaN     0.257790          NaN  0.218116       NaN
# 5         0.880589           NaN     0.268968          NaN  0.055433       NaN
# 6         0.888359           NaN     0.309641          NaN  0.101561       NaN
# 7         0.892714           NaN     0.319969          NaN  0.052886       NaN
# 8         0.892188           NaN     0.312659          NaN  0.360368       NaN
# 9         0.900109           NaN     0.382545          NaN  0.297828       NaN
# 10        0.899996           NaN     0.372906          NaN  0.420345       NaN

# %%
cnn.plot(y=['loss.chr', 'loss.pho'], figsize=(15, 10))

# %%
print(max(cnn['f-score.chr']), max(cnn['f-score.pho']))
cnn.plot(y=['accuracy.chr', 'accuracy.pho', 'f-score.chr', 'f-score.pho'], figsize=(15, 10))
# Out:
# 0.538024971623 nan
