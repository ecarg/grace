# %% [markdown]
# Version 0.4
# ====
#
# 추가한 내용
# ----
# * gazetteer 매핑 여부를 one hot 벡터로 만들어 각 음절 뒤에 추가
# * 50 임베딩 차원 => 50 임베딩 차원 + 15 one hot 차원

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# FNN
# ----
#
# ### 음절(chr), 자소(pho)

# %%
fnn_chr = pd.DataFrame.from_csv('v0.4/fnn4.chr.tsv', sep='\t')
fnn_chr.columns = ['loss.chr', 'accuracy.chr', 'f-score.chr']
print(fnn_chr[:5])
print()
fnn_pho = pd.DataFrame.from_csv('v0.4/fnn4.pho.tsv', sep='\t')
fnn_pho.columns = ['loss.pho', 'accuracy.pho', 'f-score.pho']
print(fnn_pho[:5])
fnn = pd.concat([fnn_chr, fnn_pho])
fnn[:10]
# Out:
#       loss.chr  accuracy.chr  f-score.chr
# iter
# 1     0.578982      0.844776     0.102798
# 2     0.379635      0.837869     0.081001
# 3     0.316140      0.861932     0.193802
# 4     0.555070      0.861857     0.176640
# 5     0.170492      0.873869     0.259321
#
#       loss.pho  accuracy.pho  f-score.pho
# iter
# 1     0.321912      0.835617     0.072061
# 2     0.834656      0.849581     0.135911
# 3     0.338804      0.837569     0.147585
# 4     0.737505      0.858178     0.149949
# 5     0.265273      0.860243     0.160264
#       accuracy.chr  accuracy.pho  f-score.chr  f-score.pho  loss.chr  loss.pho
# iter
# 1         0.844776           NaN     0.102798          NaN  0.578982       NaN
# 2         0.837869           NaN     0.081001          NaN  0.379635       NaN
# 3         0.861932           NaN     0.193802          NaN  0.316140       NaN
# 4         0.861857           NaN     0.176640          NaN  0.555070       NaN
# 5         0.873869           NaN     0.259321          NaN  0.170492       NaN
# 6         0.884718           NaN     0.291910          NaN  0.008382       NaN
# 7         0.892939           NaN     0.338217          NaN  1.194182       NaN
# 8         0.896242           NaN     0.342482          NaN  0.691006       NaN
# 9         0.897819           NaN     0.354893          NaN  0.616343       NaN
# 10        0.900672           NaN     0.378849          NaN  0.127215       NaN

# %%
fnn.plot(y=['loss.chr', 'loss.pho'], figsize=(15, 10))

# %%
print(max(fnn['f-score.chr']), max(fnn['f-score.pho']))
fnn.plot(y=['accuracy.chr', 'accuracy.pho', 'f-score.chr', 'f-score.pho'], figsize=(15, 10))
# Out:
# 0.573201898503 nan

# %% [markdown]
# CNN
# ----
#
# ### 음절(chr), 자소(pho)

# %%
cnn_chr = pd.DataFrame.from_csv('v0.4/cnn4.chr.tsv', sep='\t')
cnn_chr.columns = ['loss.chr', 'accuracy.chr', 'f-score.chr']
print(cnn_chr[:5])
print()
cnn_pho = pd.DataFrame.from_csv('v0.4/cnn4.pho.tsv', sep='\t')
cnn_pho.columns = ['loss.pho', 'accuracy.pho', 'f-score.pho']
print(cnn_pho[:5])
cnn = pd.concat([cnn_chr, cnn_pho])
cnn[:10]
# Out:
#       loss.chr  accuracy.chr  f-score.chr
# iter
# 1     0.648623      0.842261     0.097473
# 2     0.634036      0.853936     0.179767
# 3     0.373699      0.862195     0.174025
# 4     0.306958      0.875145     0.219533
# 5     0.514494      0.884755     0.277012
#
#       loss.pho  accuracy.pho  f-score.pho
# iter
# 1     0.928554      0.827771     0.000000
# 2     0.143989      0.844739     0.112532
# 3     0.415018      0.852847     0.162415
# 4     0.332221      0.852097     0.164251
# 5     0.886693      0.867750     0.243069
#       accuracy.chr  accuracy.pho  f-score.chr  f-score.pho  loss.chr  loss.pho
# iter
# 1         0.842261           NaN     0.097473          NaN  0.648623       NaN
# 2         0.853936           NaN     0.179767          NaN  0.634036       NaN
# 3         0.862195           NaN     0.174025          NaN  0.373699       NaN
# 4         0.875145           NaN     0.219533          NaN  0.306958       NaN
# 5         0.884755           NaN     0.277012          NaN  0.514494       NaN
# 6         0.891888           NaN     0.329605          NaN  0.565044       NaN
# 7         0.893127           NaN     0.334790          NaN  0.135855       NaN
# 8         0.888997           NaN     0.355047          NaN  0.317578       NaN
# 9         0.897932           NaN     0.356856          NaN  0.125127       NaN
# 10        0.896993           NaN     0.365924          NaN  0.093334       NaN

# %%
cnn.plot(y=['loss.chr', 'loss.pho'], figsize=(15, 10))

# %%
print(max(cnn['f-score.chr']), max(cnn['f-score.pho']))
cnn.plot(y=['accuracy.chr', 'accuracy.pho', 'f-score.chr', 'f-score.pho'], figsize=(15, 10))
# Out:
# 0.570813911796 nan
